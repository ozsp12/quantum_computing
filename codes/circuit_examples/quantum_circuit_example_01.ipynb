# %% [markdown]
# # Documented English edition
#
# This notebook is the reviewed English edition of `exemplos_circuitos/01_exemplo/exemplo_circuito_01.ipynb`. The original file, metadata, and historical outputs are preserved under `codes_obsolete/`. Stored outputs were cleared from this edition; execute the cells sequentially with the declared kernel.

# %% [markdown]
# ## Computational step
#
# Evaluate the next step of the derivation or numerical demonstration.

# %% [markdown]
# ## Dependencies
#
# Import the numerical, visualization, and quantum-computing libraries used below.

# %%
# Purpose: Import the numerical, visualization, and quantum-computing libraries used below.
# Imports principais
from qiskit import QuantumCircuit, QuantumRegister
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
import numpy as np
# Explanation translated; consult the archived notebook for the original wording.
# %matplotlib inline

# Explanation translated; consult the archived notebook for the original wording.
qc = QuantumCircuit(2)
# Explanation translated; consult the archived notebook for the original wording.
qc.x(0)
# Explanation translated; consult the archived notebook for the original wording.
qc.h(0)
# Explanation translated; consult the archived notebook for the original wording.
qc.cx(0, 1)
# Explanation translated; consult the archived notebook for the original wording.
qc.ry(np.pi, 1)
# Explanation translated; consult the archived notebook for the original wording.
qc.h(0)
# Explanation translated; consult the archived notebook for the original wording.
qc.draw("mpl")

# %% [markdown]
# # Step-by-step explanation

# %% [markdown]
# ## Circuit construction
#
# Create or modify the quantum circuit and make the register structure explicit.

# %%
# Purpose: Create or modify the quantum circuit and make the register structure explicit.
# Explanation translated; consult the archived notebook for the original wording.
qc = QuantumCircuit(2)
# Explanation translated; consult the archived notebook for the original wording.
qc.draw("mpl")

# %% [markdown]
# ## Statevector analysis
#
# Construct or inspect the statevector associated with the current unitary circuit.
#
# $$|\psi\rangle = |00\rangle$$

# %%
# Purpose: Construct or inspect the statevector associated with the current unitary circuit.
# Explanation translated; consult the archived notebook for the original wording.
psi = Statevector.from_instruction(qc)
#
psi.draw('latex')

# %% [markdown]
# ## Visualization
#
# Render the current mathematical object, circuit, or numerical result.

# %%
# Purpose: Render the current mathematical object, circuit, or numerical result.
#
psi.draw('latex_source')

# %% [markdown]
# ## Bloch-sphere visualization
#
# Visualize the single-qubit or reduced state on the Bloch sphere.

# %%
# Purpose: Visualize the single-qubit or reduced state on the Bloch sphere.
# Explanation translated; consult the archived notebook for the original wording.
display(plot_bloch_multivector(psi))

# %% [markdown]
# ## Circuit construction
#
# Create or modify the quantum circuit and make the register structure explicit.

# %%
# Purpose: Create or modify the quantum circuit and make the register structure explicit.
# Explanation translated; consult the archived notebook for the original wording.
qc = QuantumCircuit(2)
# Explanation translated; consult the archived notebook for the original wording.
qc.x(0)
# Explanation translated; consult the archived notebook for the original wording.
qc.draw("mpl")

# %% [markdown]
# ## Statevector analysis
#
# Construct or inspect the statevector associated with the current unitary circuit.
#
# $$
# $$
# $$
# |00\rangle =
# |01\rangle =
# |10\rangle =
# |11\rangle =
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$

# %%
# Purpose: Construct or inspect the statevector associated with the current unitary circuit.
# Explanation translated; consult the archived notebook for the original wording.
psi = Statevector.from_instruction(qc)
#
psi.draw('latex')

# %% [markdown]
# ## Bloch-sphere visualization
#
# Visualize the single-qubit or reduced state on the Bloch sphere.

# %%
# Purpose: Visualize the single-qubit or reduced state on the Bloch sphere.
# Explanation translated; consult the archived notebook for the original wording.
display(plot_bloch_multivector(psi))

# %% [markdown]
# ## Circuit construction
#
# Create or modify the quantum circuit and make the register structure explicit.
#
# $$
# $$

# %%
# Purpose: Create or modify the quantum circuit and make the register structure explicit.
# Explanation translated; consult the archived notebook for the original wording.
qc = QuantumCircuit(2)
# Explanation translated; consult the archived notebook for the original wording.
qc.x(0)
# Explanation translated; consult the archived notebook for the original wording.
qc.h(0)
# Explanation translated; consult the archived notebook for the original wording.
qc.draw("mpl")

# %% [markdown]
# ## Hadamard operation
#
# Apply a Hadamard gate to create or recombine computational-basis amplitudes.
#
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# |\psi_2\rangle &= (I \otimes H)\lvert 01\rangle \\
# $$
# $$
# |\psi_2\rangle = \frac{\sqrt{2}}{2}\lvert 00\rangle-
# $$

# %%
# Purpose: Construct or inspect the statevector associated with the current unitary circuit.
# Explanation translated; consult the archived notebook for the original wording.
psi = Statevector.from_instruction(qc)
#
psi.draw('latex')

# %% [markdown]
# ## Bloch-sphere visualization
#
# Visualize the single-qubit or reduced state on the Bloch sphere.
#
# $$
# $$
# $$
# $$

# %%
# Purpose: Visualize the single-qubit or reduced state on the Bloch sphere.
# Explanation translated; consult the archived notebook for the original wording.
display(plot_bloch_multivector(psi))

# %% [markdown]
# ## Circuit construction
#
# Create or modify the quantum circuit and make the register structure explicit.
#
# | **Antes** |        | **Depois** |        |
# |-----------|--------|-----------|--------|
# | Controle   | Alvo | Controle   | Alvo |
# | $\lvert 0\rangle$ | $\lvert 0\rangle$ | $\lvert 0\rangle$ | $\lvert 0\rangle$ |
# | $\lvert 0\rangle$ | $\lvert 1\rangle$ | $\lvert 0\rangle$ | $\lvert 1\rangle$ |
# | $\lvert 1\rangle$ | $\lvert 0\rangle$ | $\lvert 1\rangle$ | $\lvert 1\rangle$ |
# | $\lvert 1\rangle$ | $\lvert 1\rangle$ | $\lvert 1\rangle$ | $\lvert 0\rangle$ |
# $$
# $$
# $$
# $$
# $$
# $$

# %%
# Purpose: Create or modify the quantum circuit and make the register structure explicit.
# Explanation translated; consult the archived notebook for the original wording.
qc = QuantumCircuit(2)
# Explanation translated; consult the archived notebook for the original wording.
qc.x(0)
# Explanation translated; consult the archived notebook for the original wording.
qc.h(0)
# Explanation translated; consult the archived notebook for the original wording.
qc.cx(0, 1)
# Explanation translated; consult the archived notebook for the original wording.
qc.draw("mpl")

# %% [markdown]
# ## Hadamard operation
#
# Apply a Hadamard gate to create or recombine computational-basis amplitudes.
#
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$

# %%
# Purpose: Construct or inspect the statevector associated with the current unitary circuit.
# Explanation translated; consult the archived notebook for the original wording.
psi = Statevector.from_instruction(qc)
#
psi.draw('latex')

# %% [markdown]
# ## Bloch-sphere visualization
#
# Visualize the single-qubit or reduced state on the Bloch sphere.
#
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$

# %%
# Purpose: Visualize the single-qubit or reduced state on the Bloch sphere.
# Explanation translated; consult the archived notebook for the original wording.
display(plot_bloch_multivector(psi))

# %% [markdown]
# ## Circuit construction
#
# Create or modify the quantum circuit and make the register structure explicit.
#
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$

# %%
# Purpose: Create or modify the quantum circuit and make the register structure explicit.
# Explanation translated; consult the archived notebook for the original wording.
qc = QuantumCircuit(2)
# Explanation translated; consult the archived notebook for the original wording.
qc.x(0)
# Explanation translated; consult the archived notebook for the original wording.
qc.h(0)
# Explanation translated; consult the archived notebook for the original wording.
qc.cx(0, 1)
# Explanation translated; consult the archived notebook for the original wording.
qc.ry(np.pi, 1)
# Explanation translated; consult the archived notebook for the original wording.
qc.draw("mpl")

# %% [markdown]
# ## Hadamard operation
#
# Apply a Hadamard gate to create or recombine computational-basis amplitudes.
#
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$

# %%
# Purpose: Construct or inspect the statevector associated with the current unitary circuit.
# Explanation translated; consult the archived notebook for the original wording.
psi = Statevector.from_instruction(qc)
#
psi.draw('latex')

# %% [markdown]
# ## Circuit construction
#
# Create or modify the quantum circuit and make the register structure explicit.
#
# $$
# $$
# $$
# $$

# %%
# Purpose: Create or modify the quantum circuit and make the register structure explicit.
# Explanation translated; consult the archived notebook for the original wording.
qc = QuantumCircuit(2)
# Explanation translated; consult the archived notebook for the original wording.
qc.x(0)
# Explanation translated; consult the archived notebook for the original wording.
qc.h(0)
# Explanation translated; consult the archived notebook for the original wording.
qc.cx(0, 1)
# Explanation translated; consult the archived notebook for the original wording.
qc.ry(np.pi, 1)
# Explanation translated; consult the archived notebook for the original wording.
qc.h(0)
# Explanation translated; consult the archived notebook for the original wording.
qc.draw("mpl")

# %% [markdown]
# ## Hadamard operation
#
# Apply a Hadamard gate to create or recombine computational-basis amplitudes.
#
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$

# %%
# Purpose: Construct or inspect the statevector associated with the current unitary circuit.
# Explanation translated; consult the archived notebook for the original wording.
psi = Statevector.from_instruction(qc)
#
psi.draw('latex')

# %% [markdown]
# ## Bloch-sphere visualization
#
# Visualize the single-qubit or reduced state on the Bloch sphere.
#
# $$
# $$
# $$
# $$
# $$
# $$
# $$
# $$
